# %%
from pathlib import Path
from visual_search_engine import SimilaritySearchEngine

image = Path("/home/anandas/test_images/Datewise/06/14/2015/IMG_0192(1).jpg")
engine = SimilaritySearchEngine(
    base_folder='/home/anandas/test_images',
    qdrant_url="http://localhost:6333",
)

embedding = engine.get_embedding(image)
results = engine.search(image, limit=20)
print(results)
# Out:
# [{'id': 8003605726527706038, 'score': 1.0000001, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0192(1).jpg')}, {'id': 6157918545921817098, 'score': 0.9996907, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0192.jpg')}, {'id': 7919072328047251631, 'score': 0.999631, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0192(4).jpg')}, {'id': 3214793459328955475, 'score': 0.9405862, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0193(3).jpg')}, {'id': 8905665622922807911, 'score': 0.9403833, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0193(1).jpg')}, {'id': 2199648080057698080, 'score': 0.93899995, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/14/2015/IMG_0193.jpg')}, {'id': 5336955551723193879, 'score': 0.8511838, 'filename': PosixPath('/home/anandas/test_images/Datewise/06/18/2020/IMG_20200618_133627.jpg')}]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img = mpimg.imread(image)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math

# Assume you already have a list of image paths
# Example:
# image_paths = [Path("/path/to/img1.jpg"), Path("/path/to/img2.png"), ...]

# Number of images per row
images_per_row = 5
n_images = len(results)
n_rows = math.ceil(n_images / images_per_row)

# Create figure
fig, axes = plt.subplots(n_rows, images_per_row, figsize=(20, 4 * n_rows))

# Flatten axes for easy iteration
axes = axes.flatten() if n_rows > 1 else axes

# Display images
for i, ax in enumerate(axes):
    if i < n_images:
        img = mpimg.imread(results[i]['filename'])
        ax.imshow(img)
        ax.set_title(f"score: {results[i]['score']}", fontsize=9)
        ax.axis('off')
    else:
        ax.axis('off')  # Hide unused subplots

plt.tight_layout()
plt.show()
