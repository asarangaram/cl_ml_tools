# %%
import time

# Setting up paths.
image_folder = Path("/home/anandas/test_images/Datewise/")
base_folder = Path("/home/anandas/test_images")
MODEL_HEF = "resnet_v1_18_feature.hef"

store = QdrantImageStore(collection_name="images")

start = time.perf_counter()
# table = create_table(DB_PATH)
process(
    hef=MODEL_HEF, base_folder=base_folder, relative_path=Path("Datewise"), vec_table=""
)
end = time.perf_counter()

print(f"Time taken: {end - start:.4f} seconds")
